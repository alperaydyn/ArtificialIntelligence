# %% [markdown]
# <a href="https://colab.research.google.com/github/alperaydyn/ArtificialIntelligence/blob/master/GoogleColabTutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img height=60 src='https://www.google.com/images/logos/google_logo_41_2x.png'><img height=90 src='https://cdn-images-1.medium.com/freeze/max/1000/1*Lad06lrjlU9UZgSTHUoyfA.png?q=20' />

# %% [markdown]
# # Giriş
#
# <style>
# h1 {background: #ddd;}
# </style>

# %% [markdown]
# ## Nedir <font color='orange'>Colab</font>
#
# «Colab, tarayıcı aracılığıyla python kodu yazma ve çalıştırmaya izin verir ve özellikle makine öğrenimi, veri analizi ve eğitim için çok uygundur. Daha teknik olarak, Colab GPU'lar da dahil olmak üzere bilgi işlem kaynaklarına ücretsiz erişim sağlarken, hiçbir kurulum gerektirmeyen, barındırılan bir Jupyter notebook servisidir.»  *https://research.google.com/colaboratory/faq.html*
#
#
# <font color='orange'>Colab</font> Tamamen ücretsizdir. Ancak <font color='gray'><b>Colab Pro</b></font> 'yu belirli bir ücret karşılığında
# * daha fazla GPU hızı
# * daha fazla RAM ve
# * daha uzun bekleme süresi*
#
# özellikleri ile kullanabilirsiniz.

# %% [markdown]
# ## Kaynaklar
# * RAM (~12 GB)
# * Disk alanı (~100 GB)
# * Çalışma süresi (90 dk, 12 saat max)
# * CPU/GPU/TPU seçenekleri

# %% [markdown]
# # Hazırlık

# %% [markdown]
# ## Oturum Açma
# https://colab.research.google.com/
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Yeni Notebook
#
# <img height=450 src="data:image/png;base64,..." />

# %% [markdown]
# #### Notebook'un drive'daki yeri
#
# <table><tr><td style='vertical-align:top;'>
# <img height=130 src="data:image/png;base64,..." />
# </td><td><img height=400 src="data:image/png;base64,..." /></td></table>

# %% [markdown]
# #### Çalışma Ortamları
#
# <img height=200 src="data:image/png;base64,..." />
# <img height=250 src="data:image/png;base64,..." />

# %% [markdown]
# ### Ortam Türleri
#
# <img height=250 src="data:image/png;base64,..." />

# %% [markdown]
# # Görünüm

# %% [markdown]
# ## Light/Dark Mode
# Tools -> Settings -> Site

# %% [markdown]
# <table><tr><td><img height=300 src="data:image/png;base64,..." /></td><td><img height=300 src="data:image/png;base64,..." /></td></table>

# %% [markdown]
# ## Cell Folding

# %% [markdown]
# <img height=300 src="data:image/png;base64,..." />

# %% [markdown]
# ## Editör Özellikleri
# Tools -> Settings -> Editor

# %% [markdown]
# * font renkleri
# * satır numaraları
# * indent özellikleri
# * code-folding
# * <b>power level</b>
#
# <img height=200 src="data:image/png;base64,..." />

# %% [markdown]
# # Paylaşım

# %% [markdown]
# <img height=400 src="data:image/png;base64,..." />

# %% [markdown]
# # Kullanım

# %% [markdown]
# ### Yeni Hücre Ekleme

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Hücre Tipleri

# %% [markdown]
# ### Komut Hücresi

# %%
print('merhaba Akbank')
# Out:
# merhaba Akbank

# %% [markdown]
# <img height=150 src="data:image/png;base64,..." />

# %% [markdown]
# ### Metin Hücresi

# %% [markdown]
# Bu bir metin hücresidir. Bu hücreyi editör araç kutusu veya html kodları ile de biçimlendirebiliriz.
#
# <font color='red'>Kırmızı metin rengi.</font>
#
# [<font color='orange'>colab link</font>](http://colab.reeearch.google.com)
#
# $
# \Large Q_(n+1) = \frac{1}{n}\sum_{i=1}^nR_i
# $
#
# Görüntü:
#
# <img height=100 src="https://colab.research.google.com/img/colab_favicon_256px.png" />
#
# <iframe width="560" height="315" src="https://www.youtube.com/watch?v=09_LlHjoEiY" frameborder="0" allowfullscreen sandbox="allow-scripts allow-same-origin allow-presentation"></iframe>

# %%
# Youtube
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/09_LlHjoEiY" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" sandbox="allow-scripts allow-same-origin allow-presentation"></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/09_LlHjoEiY" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" sandbox="allow-scripts allow-same-origin allow-presentation"></iframe>

# %% [markdown]
# ## Hücre İşlemleri

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Formlar

# %%
#@title Example form fields
#@markdown Forms support many types of fields.

no_type_checking = ''  #@param
string_type = 'example'  #@param {type: "string"}
slider_value = 171  #@param {type: "slider", min: 100, max: 200}
number = 102  #@param {type: "number"}
date = '2020-03-01'  #@param {type: "date"}
pick_me = "monday"  #@param ['monday', 'tuesday', 'wednesday', 'thursday']
select_or_input = "apples" #@param ["apples", "bananas", "oranges"] {allow-input: true}
#@markdown ---

# %% [markdown]
# # Kodlama

# %% [markdown]
# # Don't Forget
#
# * install libraries
# * code running after browser close
# * drive mount
# * code commenting
# * fancy features, sparkles
# * cell formatting, insert images, html tags
# * collaboration, shared files
# * cell commands, move up/down, delete, comment,
# * remote runtime, train model, download then run in local
# * [Colab from VS Code](https://stackoverflow.com/questions/59508225/is-it-possible-to-connect-vscode-on-a-local-machine-with-google-colab-the-fre)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
